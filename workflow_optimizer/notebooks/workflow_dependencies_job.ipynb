# %%
from loguru import logger

# Remove default handlers
logger.remove()

# Add handler for level INFO and above
logger.add(lambda msg: print(msg, end=''), level="INFO")
# Out:
# 1

# %%
from workflow_optimizer.job_dependency_analyzer_nx import JobDependencyAnalyzerNX as JobDependencyAnalyzer

wf_folder = "/home_nfs/mimounis/iosea-wp3-recommandation-system/dataset_generation/dataset_deep/ECMWF-649c3c40cc9340246f87cb58"


analyzer = JobDependencyAnalyzer(workflow_folder=wf_folder)
print(analyzer.sorted_jobs)
analyzer.analyze_dependencies()
analyzer.analyze_dependencies

analyzer.dump_edges_to_json()
plt = analyzer.plot_gantt_chart()
plt.grid()
plt.show()

# fig = analyzer.create_gantt_chart()
# fig.show()
# Out:
# 2023-11-13 16:27:50.952 | INFO     | workflow_optimizer.job_dependency_analyzer_nx:extract_and_sort_jobs:43 - Jobs extracted and sorted by start time.
# 2023-11-13 16:27:50.953 | INFO     | workflow_optimizer.job_dependency_analyzer_nx:analyze_dependencies:105 - Dependencies analyzed and graph populated.
# 2023-11-13 16:27:50.954 | DEBUG    | workflow_optimizer.job_dependency_analyzer_nx:find_nodes_with_multiple_incoming_edges:119 - Finding nodes with multiple incoming edges.
# 2023-11-13 16:27:50.956 | DEBUG    | workflow_optimizer.job_dependency_analyzer_nx:find_nodes_with_multiple_incoming_edges:132 - Nodes with multiple incoming edges: [('371902', 2), ('371905', 3), ('371904', 4), ('371906', 5), ('371907', 6), ('371908', 7), ('371909', 8), ('371910', 9), ('371911', 10), ('371912', 11), ('371913', 12), ('371924', 13)]
# 2023-11-13 16:27:50.957 | DEBUG    | workflow_optimizer.job_dependency_analyzer_nx:clean_redundancy:176 - Cleaning redundancies for node: 371902
# ...
